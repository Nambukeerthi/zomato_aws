# %%
import json
import pandas as pd
import numpy as np

#file_path = "file1.json"
#with open(file_path, "r") as f:
#    data1 = json.load(f)
#len(data1)
#data1[0]['restaurants'][5]

# %%
# LISTED DATA INTO DATAFRAME
df1 = pd.DataFrame([row.split(", ") for row in dataF], columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range','Cuisines','Average_cost','Rating_text','Rating_color','Rating_votes','Rating','Address','City','City_id','Country_id','Locality'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # LISTED DATA INTO DATAFRAME
# ----> 2 df1 = pd.DataFrame([row.split(", ") for row in dataF], columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range','Cuisines','Average_cost','Rating_text','Rating_color','Rating_votes','Rating','Address','City','City_id','Country_id','Locality'])
#
# NameError: name 'dataF' is not defined

# %%
df1

# %%
import json
def json_function(data):
 dataF=[]   


 for i in data:
    if 'restaurants' in i:
        #print(i)
      for j in i: 
        for j in i['restaurants']:
        #print(j)   
            
            #if 'price_range' in j['restaurant']: 
            price_range1 = (j['restaurant'].get('price_range', 'Key not found'))
            #if 'name' in j['restaurant']:  
            res_name1 = (j['restaurant'].get('name', 'Key not found'))  
            res_id1 = (j['restaurant']['R'].get('res_id', 'Key not found'))   
            cuisines1 = (j['restaurant'].get('cuisines', 'Key not found').replace(",", " "))
            average_cost1 = (j['restaurant'].get('average_cost_for_two', 'Key not found'))
            
            rating_text1 = (j['restaurant']['user_rating'].get('rating_text', 'Key not found'))
            rating_color1 = (j['restaurant']['user_rating'].get('rating_color', 'Key not found'))
            rating_votes1 = (j['restaurant']['user_rating'].get('votes', 'Key not found'))
            rating_aggre1 = (j['restaurant']['user_rating'].get('aggregate_rating', 'Key not found'))
            
            #for l in j['restaurant']['location']:    
            address1 = (j['restaurant']['location'].get('address', 'Key not found').replace(",", " "))  
            city1 = (j['restaurant']['location'].get('city', 'Key not found').replace(",", " "))
            country_id1 = (j['restaurant']['location'].get('country_id', 'Key not found'))
            locality_verbose1 = (j['restaurant']['location'].get('locality_verbose', 'Key not found').replace(",", " "))
            city_id1 = (j['restaurant']['location'].get('city_id', 'Key not found'))
            
        #print(price_range1,", ",res_name1,", ",res_id1,", ",address1,".")      
            print_data= (res_name1, res_id1, price_range1, cuisines1,average_cost1, rating_text1, rating_color1, rating_votes1, rating_aggre1, address1, city1, city_id1, country_id1, locality_verbose1)    
            dataF.append(", ".join(map(str, print_data)))        
            # LISTED DATA INTO DATAFRAME
            
  
 return dataF



file_path1 = 'file1.json'
with open(file_path1, "r") as a:
 data1 = json.load(a)
returned_data1 =  json_function(data1) 
df1 = pd.DataFrame([row.split(", ") for row in returned_data1], columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range','Cuisines','Average_cost','Rating_text',
                                                               'Rating_color','Rating_votes','Rating','Address','City','City_id','Country_id','Locality'])

#------------------------------------------------------
file_path2 = 'file2.json'
with open(file_path2, "r") as b:
 data2 = json.load(b)
returned_data2 =  json_function(data2)

max_columns = 14  # or whatever your intended number of columns is
dataF2_fixed = []

for row in returned_data2:
    row_values = row.split(',')
    if len(row_values) > max_columns:
        row_values = row_values[:max_columns]  # Truncate to the desired number of columns
    elif len(row_values) < max_columns:
        row_values.extend([''] * (max_columns - len(row_values)))  # Add empty values for missing columns
    dataF2_fixed.append(row_values)

# Now create the DataFrame with consistent data
df2 = pd.DataFrame(dataF2_fixed, columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range', 'Cuisines', 'Average_cost',
                                           'Rating_text', 'Rating_color', 'Rating_votes', 'Rating', 'Address', 'City',
                                           'City_id', 'Country_id', 'Locality'])
#------------------------------------------------------
file_path3 = 'file3.json'
with open(file_path3, "r") as c:
 data3 = json.load(c)
returned_data3=  json_function(data3)

max_columns = 14  # or whatever your intended number of columns is
dataF3_fixed = []

for row in returned_data3:
    row_values = row.split(',')
    if len(row_values) > max_columns:
        row_values = row_values[:max_columns]  # Truncate to the desired number of columns
    elif len(row_values) < max_columns:
        row_values.extend([''] * (max_columns - len(row_values)))  # Add empty values for missing columns
    dataF3_fixed.append(row_values)

# Now create the DataFrame with consistent data
df3 = pd.DataFrame(dataF3_fixed, columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range', 'Cuisines', 'Average_cost',
                                           'Rating_text', 'Rating_color', 'Rating_votes', 'Rating', 'Address', 'City',
                                           'City_id', 'Country_id', 'Locality'])

#----------------------------------------------------
file_path4 = 'file4.json'
with open(file_path4, "r") as d:
 data4 = json.load(d)
returned_data4 =  json_function(data4)

max_columns = 14  # or whatever your intended number of columns is
dataF4_fixed = []

for row in returned_data4:
    row_values = row.split(',')
    if len(row_values) > max_columns:
        row_values = row_values[:max_columns]  # Truncate to the desired number of columns
    elif len(row_values) < max_columns:
        row_values.extend([''] * (max_columns - len(row_values)))  # Add empty values for missing columns
    dataF4_fixed.append(row_values)

# Now create the DataFrame with consistent data
df4 = pd.DataFrame(dataF4_fixed, columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range', 'Cuisines', 'Average_cost',
                                           'Rating_text', 'Rating_color', 'Rating_votes', 'Rating', 'Address', 'City',
                                           'City_id', 'Country_id', 'Locality'])

#-----------------------------------------
file_path5 = 'file5.json'
with open(file_path5, "r") as e:
 data5 = json.load(e)
returned_data5 =  json_function(data5)

max_columns = 14  # or whatever your intended number of columns is
dataF5_fixed = []

for row in returned_data5:
    row_values = row.split(',')
    if len(row_values) > max_columns:
        row_values = row_values[:max_columns]  # Truncate to the desired number of columns
    elif len(row_values) < max_columns:
        row_values.extend([''] * (max_columns - len(row_values)))  # Add empty values for missing columns
    dataF5_fixed.append(row_values)

# Now create the DataFrame with consistent data
df5 = pd.DataFrame(dataF5_fixed, columns=['Restaurant_Name', 'Restaurant_ID', 'Price_range', 'Cuisines', 'Average_cost',
                                           'Rating_text', 'Rating_color', 'Rating_votes', 'Rating', 'Address', 'City',
                                           'City_id', 'Country_id', 'Locality'])

# %%
df_concat = pd.concat([df1, df2,df3,df4,df5], ignore_index=True)

df_original = df_concat.drop_duplicates(ignore_index=True)

# %%
df_original.head()
# Out:
#               Restaurant_Name Restaurant_ID Price_range  \
# 0            Hauz Khas Social        308322           3
# 1  Qubitos - The Terrace Cafe      18037817           3
# 2             The Hudson Cafe        312345           2
# 3           Summer House Cafe        307490           3
# 4                 38 Barracks      18241537           3
#
#                                             Cuisines Average_cost Rating_text  \
# 0         Continental  American  Asian  North Indian         1600   Very Good
# 1  Thai  European  Mexican  North Indian  Chinese...         1500   Excellent
# 2                Cafe  Italian  Continental  Chinese          850   Very Good
# 3                               Italian  Continental         1850   Very Good
# 4             North Indian  Italian  Asian  American         1600   Very Good
#
#   Rating_color Rating_votes Rating  \
# 0       5BA829         7931    4.3
# 1       3F7E00          778    4.5
# 2       5BA829         1537    4.4
# ...

# %%
pd.set_option('display.max_rows', None)
viz =df_original[['City', 'City_id']].drop_duplicates()
viz
# Out:
#                                                    City  \
# 0                                             New Delhi
# 6                                               Gurgaon
# 20                                              Kolkata
# 40                                               Mumbai
# 60                                            Bangalore
# 80                                                 Pune
# 100                                           Hyderabad
# 112                                        Secunderabad
# 120                                             Chennai
# 140                                             Lucknow
# 160                                               Kochi
# 180                                              Jaipur
# 200                                           Ahmedabad
# 220                                          Chandigarh
# 232                                              Mohali
# 233                                           Panchkula
# ...

# %%
pd.set_option('display.max_rows', None)
viz1 =df_original[['City_id','Country_id']].drop_duplicates()
viz1
# Out:
#                                                 City_id  Country_id
# 0                                                     1           1
# 20                                                    2           1
# 40                                                    3           1
# 60                                                    4           1
# 80                                                    5           1
# 100                                                   6           1
# 120                                                   7           1
# 140                                                   8           1
# 160                                                   9           1
# 180                                                  10           1
# 200                                                  11           1
# 220                                                  12           1
# 240                                                  13           1
# ...

# %%
#pd.set_option('display.max_rows', None)
#df_original['Rating_text']

# %%
df_original['Rating_text'].str.count('North Indian  Chinese  Continental  Italian').sum()
# Out:
# 1

# %%
df_original['Rating_text'].str.count('Continental  American  Italian  Bakery').sum()
# Out:
# 1

# %%
df_original['Rating_text'].str.count('350').sum()
# Out:
# 7

# %%
df_original['Rating_text'].str.count('Chinese  North Indian').sum()
# Out:
# 1

# %%
df_original['Cuisines'].unique()
# Out:
# array(['Continental  American  Asian  North Indian',
#        'Thai  European  Mexican  North Indian  Chinese  Cafe',
#        'Cafe  Italian  Continental  Chinese', ..., ' Indian  Persian',
#        ' Desserts  Thai', ' American  Greek'], dtype=object)

# %%
df_original['Rating_text'].unique()
# Out:
# array(['Very Good', 'Excellent', 'Poor', 'Good', 'Average', 'Not rated',
#        ' Average', ' Excellent', ' Very Good', ' Good', ' Poor',
#        ' Not rated', ' 350',
#        ' North Indian  Chinese  Continental  Italian',
#        ' Chinese  North Indian', ' 200', ' 300', ' 250',
#        ' Continental  American  Italian  Bakery', ' 40'], dtype=object)

# %%
df_original
# Out:
#                     Restaurant_Name Restaurant_ID Price_range  \
# 0                  Hauz Khas Social        308322           3
# 1        Qubitos - The Terrace Cafe      18037817           3
# 2                   The Hudson Cafe        312345           2
# 3                 Summer House Cafe        307490           3
# 4                       38 Barracks      18241537           3
# ...                             ...           ...         ...
# 9597                  Senor Iguanas      17582627           1
# 9598  Sandpiper Restaurant & Lounge      17582625           3
# 9599                Texas Roadhouse      17582668           3
# 9600                 Riverwalk Cafe      17582498           1
# 9601                    Royal Hotel      17582499           1
#
#                                                Cuisines Average_cost  \
# 0            Continental  American  Asian  North Indian         1600
# 1     Thai  European  Mexican  North Indian  Chinese...         1500
# ...

# %%
#df_original['Cuisines'] = df_original['Cuisines'].str.replace('Continental', '', regex=True)
#df_original['Cuisines'] = df_original['Cuisines'].str.replace('North Indian', 'NorthIndian', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Very Good', 'Very Good', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Excellent', 'Excellent', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Poor', 'Poor', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Average', 'Average', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Not rated', 'Not rated', regex=True)
#df_original['Rating_text'] = df_original['Rating_text'].str.replace(' Good', 'Good', regex=True)


df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Continental', '', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Modern', '', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('North Indian', 'NorthIndian', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('North Indian ', 'NorthIndian', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('South Indian', 'SouthIndian', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Fast Food', 'FastFood', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Raw Meats', 'RawMeats', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Street Food', 'StreetFood', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('North Eastern', 'NorthEastern', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Finger Food', 'FingerFood', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Ice Cream', 'IceCream', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Chinese ', 'Chinese', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('British ', 'British', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Asian ', 'Asian', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Healthy Food', 'HealthyFood', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Mughlai ', 'Mughlai', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Coffee and Tea', 'Coffee-Tea', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Italian ', 'Italian', regex=True)
df_original.loc[:, 'Cuisines'] = df_original['Cuisines'].str.replace('Cafe  ', 'Cafe ', regex=True)

df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Very Good', 'Very Good', regex=True)
df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Excellent', 'Excellent', regex=True)
df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Good', 'Good', regex=True)
df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Poor', 'Poor', regex=True)
df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Average', 'Average', regex=True)
df_original.loc[:, 'Rating_text'] = df_original['Rating_text'].str.replace(' Not rated', 'Not rated', regex=True)



df_original = df_original[~df_original['Rating_text'].isin([' North Indian  Chinese  Continental  Italian', ' Continental  American  Italian  Bakery',' Chinese  North Indian',' 350',' 200',' 300',' 250',' 40'])]

# %%
df_original['Rating_text'].unique()
# Out:
# array(['VeryGood', 'Excellent', 'Poor', 'Good', 'Average', 'Not rated'],
#       dtype=object)

# %%
#pd.set_option('display.max_rows', None)
df_original['Cuisines']
# Out:
# 0                             American  Asian NorthIndian
# 1       Thai  European  Mexican  NorthIndian  Chinese ...
# 2                                  Cafe Italian   Chinese
# 3                                                Italian
# 4                     NorthIndian  Italian Asian American
#                               ...
# 9597                                              Mexican
# 9598                             American  Seafood  Steak
# 9599                                 American  BBQ  Steak
# 9600                                           Asian Thai
# 9601                                      Pizza  Bar Food
# Name: Cuisines, Length: 9585, dtype: object

# %%
df_original.shape
# Out:
# (9585, 14)

# %%
df_ML = df_original[['Cuisines', 'Rating_text','Rating','City_id','Country_id','Average_cost']]
df_ML.to_csv('zomato_ml.csv', index=False)
df_ML

# %%
duplicates = df_original[df_original.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Restaurant_Name, Restaurant_ID, Price_range, Cuisines, Average_cost, Rating_text, Rating_color, Rating_votes, Rating, Address, City, City_id, Country_id, Locality]
# Index: []

# %%
data1[0]['restaurants'][0]['restaurant']['photos_url']
# Out:
# 'https://www.zomato.com/HauzKhasSocial/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop'

# %%
data1[0]
# Out:
# {'results_found': 17151,
#  'restaurants': [{'restaurant': {'has_online_delivery': 1,
#     'photos_url': 'https://www.zomato.com/HauzKhasSocial/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'url': 'https://www.zomato.com/HauzKhasSocial?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'price_range': 3,
#     'apikey': 'b90e6a8c738410315a20c449fe2eb1b1',
#     'user_rating': {'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'votes': '7931',
#      'aggregate_rating': '4.3'},
#     'R': {'res_id': 308322},
#     'name': 'Hauz Khas Social',
#     'cuisines': 'Continental, American, Asian, North Indian',
#     'is_delivering_now': 0,
#     'deeplink': 'zomato://restaurant/308322',
#     'menu_url': 'https://www.zomato.com/HauzKhasSocial/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'average_cost_for_two': 1600,
# ...
